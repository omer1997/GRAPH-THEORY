# %%
import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
ox.config(log_console=True, use_cache=True)
from geopy.geocoders import Nominatim
locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng
#41.931225, -88.7652508
#41.93156, -88.76494
start_latlng = (41.931361, -88.7653257)
end_latlng = (41.74531085, -88.85733441)
start_location = "NIU Computer Science Building"
end_location = "Shabbona Lake State Park "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.74531085, -88.85733441))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.74531085, -88.85733441)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:46:59 Configured OSMnx 1.1.2
# 2022-05-02 16:46:59 HTTP response caching is on
# 2022-05-02 16:47:00 Retrieved response from cache file "cache/c11ac066b50965cb15fc132a0984ee25d209eecc.json"
# 2022-05-02 16:47:00 Created GeoDataFrame with 1 rows from 1 queries
# 2022-05-02 16:47:00 Constructed place geometry polygon(s) to query API
# 2022-05-02 16:47:00 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:00 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:00 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:00 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:00 Requesting data within polygon from API in 1 request(s)
# 2022-05-02 16:47:00 Retrieved response from cache file "cache/4df14a153707c0ba5aa56049b590b0cca3d22b69.json"
# 2022-05-02 16:47:00 Got all network data within polygon from API in 1 request(s)
# 2022-05-02 16:47:00 Creating graph from downloaded OSM data...
# 2022-05-02 16:47:00 Created graph with 37789 nodes and 77938 edges
# 2022-05-02 16:47:01 Added length attributes to graph edges
# 2022-05-02 16:47:01 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:01 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:02 Created r-tree spatial index for 37789 geometries
# 2022-05-02 16:47:02 Identified 35730 geometries inside polygon
# 2022-05-02 16:47:03 Removed 2059 nodes outside polygon
# 2022-05-02 16:47:03 Truncated graph by polygon
# 2022-05-02 16:47:03 Begin topologically simplifying the graph...
# 2022-05-02 16:47:03 Identified 4605 edge endpoints
# 2022-05-02 16:47:05 Simplified graph: 35730 to 4605 nodes, 73870 to 13006 edges
# 2022-05-02 16:47:05 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:05 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:05 Created r-tree spatial index for 4605 geometries
# 2022-05-02 16:47:05 Identified 4336 geometries inside polygon
# 2022-05-02 16:47:05 Removed 269 nodes outside polygon
# 2022-05-02 16:47:05 Removed 4 isolated nodes
# 2022-05-02 16:47:06 Got largest weakly connected component (4281 of 4332 total nodes)
# 2022-05-02 16:47:06 Truncated graph by polygon
# 2022-05-02 16:47:06 Counted undirected street segments incident on each node
# 2022-05-02 16:47:06 graph_from_polygon returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:06 graph_from_place returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:06 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:06 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:06 Created edges GeoDataFrame from graph
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_888b8b9aa67f5dcb5b73516ea5ba4230 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_888b8b9aa67f5dcb5b73516ea5ba4230&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_888b8b9aa67f5dcb5b73516ea5ba4230 = L.map(
#                 &quot;map_888b8b9aa67f5dcb5b73516ea5ba4230&quot;,
#                 {
#                     center: [41.84223808179621, -88.81266379926882],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_225c283dcd706204ff888ba15d26adb7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_888b8b9aa67f5dcb5b73516ea5ba4230);
#
#
#             var poly_line_1ee2349417b92c991c3a9d6d1ecfc8bc = L.polyline(
#                 [[41.9310983, -88.7657202], [41.9311003, -88.7656101], [41.9310945, -88.7653769], [41.931068, -88.7643183], [41.9310162, -88.7621854], [41.9310134, -88.7620636]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_888b8b9aa67f5dcb5b73516ea5ba4230);
#
#
#             var poly_line_f6e0b6f0450cd6f2edb5be7fab7d156a = L.polyline(
#                 [[41.9310134, -88.7620636], [41.9310064, -88.7619133], [41.9309447, -88.7601414], [41.9309375, -88.7598723], [41.9309365, -88.7598429], [41.9309321, -88.7596023], [41.9309212, -88.7592657], [41.9309191, -88.7592023], [41.9309098, -88.7588971], [41.9309013, -88.7586156], [41.9308867, -88.7581352]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_888b8b9aa67f5dcb5b73516ea5ba4230);
#
#
#             var poly_line_f8b4bb95ea1f5e53330bcff1afe8116c = L.polyline(
#                 [[41.9308867, -88.7581352], [41.9307985, -88.7581387], [41.9307787, -88.7581395], [41.9307403, -88.7581413], [41.9303991, -88.7581936], [41.930009, -88.7582935]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_888b8b9aa67f5dcb5b73516ea5ba4230);
#
#
#             var poly_line_96aefae9df907f2b776549842c71007f = L.polyline(
#                 [[41.930009, -88.7582935], [41.929898, -88.7583239], [41.929788, -88.7583475]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_888b8b9aa67f5dcb5b73516ea5ba4230);
#
#
#             var poly_line_f1f0cee9c19228399349bb58eca8631a = L.polyline(
#                 [[41.929788, -88.7583475], [41.9296777, -88.7583779], [41.9295161, -88.758392], [41.9294082, -88.758391], [41.928994, -88.758409], [41.9284239, -88.7584316], [41.928344, -88.758435]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8

# %%
#SUBWAY
import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim

ox.config(log_console=True, use_cache=True)
locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng

start_latlng = (41.931361, -88.7653257)
end_latlng = (41.93055745, -88.7709822)
start_location = "NIU Computer Science Building"
end_location = "Subway (928 W Lincoln Hwy) Dekalb "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.93055745, -88.7709822))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.93055745, -88.7709822)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:47:06 Configured OSMnx 1.1.2
# 2022-05-02 16:47:06 HTTP response caching is on
# 2022-05-02 16:47:07 Retrieved response from cache file "cache/c11ac066b50965cb15fc132a0984ee25d209eecc.json"
# 2022-05-02 16:47:07 Created GeoDataFrame with 1 rows from 1 queries
# 2022-05-02 16:47:07 Constructed place geometry polygon(s) to query API
# 2022-05-02 16:47:07 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:07 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:07 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:07 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:07 Requesting data within polygon from API in 1 request(s)
# 2022-05-02 16:47:07 Retrieved response from cache file "cache/4df14a153707c0ba5aa56049b590b0cca3d22b69.json"
# 2022-05-02 16:47:07 Got all network data within polygon from API in 1 request(s)
# 2022-05-02 16:47:07 Creating graph from downloaded OSM data...
# 2022-05-02 16:47:07 Created graph with 37789 nodes and 77938 edges
# 2022-05-02 16:47:07 Added length attributes to graph edges
# 2022-05-02 16:47:07 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:08 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:09 Created r-tree spatial index for 37789 geometries
# 2022-05-02 16:47:09 Identified 35730 geometries inside polygon
# 2022-05-02 16:47:09 Removed 2059 nodes outside polygon
# 2022-05-02 16:47:09 Truncated graph by polygon
# 2022-05-02 16:47:10 Begin topologically simplifying the graph...
# 2022-05-02 16:47:10 Identified 4605 edge endpoints
# 2022-05-02 16:47:12 Simplified graph: 35730 to 4605 nodes, 73870 to 13006 edges
# 2022-05-02 16:47:12 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:12 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:12 Created r-tree spatial index for 4605 geometries
# 2022-05-02 16:47:12 Identified 4336 geometries inside polygon
# 2022-05-02 16:47:12 Removed 269 nodes outside polygon
# 2022-05-02 16:47:12 Removed 4 isolated nodes
# 2022-05-02 16:47:12 Got largest weakly connected component (4281 of 4332 total nodes)
# 2022-05-02 16:47:12 Truncated graph by polygon
# 2022-05-02 16:47:12 Counted undirected street segments incident on each node
# 2022-05-02 16:47:12 graph_from_polygon returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:12 graph_from_place returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:13 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:13 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:13 Created edges GeoDataFrame from graph
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b035dac1bb30e9f9d3e09ec64567523 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b035dac1bb30e9f9d3e09ec64567523&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3b035dac1bb30e9f9d3e09ec64567523 = L.map(
#                 &quot;map_3b035dac1bb30e9f9d3e09ec64567523&quot;,
#                 {
#                     center: [41.93110422325747, -88.76827923333634],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b517cbdf97bc95417aa8a2d1c939fb52 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b035dac1bb30e9f9d3e09ec64567523);
#
#
#             var poly_line_3be08a2141205e03911935c8de4237b0 = L.polyline(
#                 [[41.9310983, -88.7657202], [41.9310995, -88.7658633], [41.9311012, -88.7659957], [41.9311206, -88.7670813], [41.9311133, -88.7671961]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3b035dac1bb30e9f9d3e09ec64567523);
#
#
#             var poly_line_c39b041d9460f564f6674182c055f5af = L.polyline(
#                 [[41.9311133, -88.7671961], [41.9311127, -88.7672543], [41.9311124, -88.7672869], [41.9311125, -88.7680504], [41.9311135, -88.7682666], [41.9311166, -88.7684946], [41.9311162, -88.7685383], [41.9311145, -88.7687523], [41.9311154, -88.7689193], [41.9311113, -88.7691356], [41.9311051, -88.7693626], [41.931106, -88.769458], [41.9311045, -88.7695301], [41.9311007, -88.769708], [41.9310984, -88.7698172], [41.931098, -88.769838], [41.9310895, -88.770057], [41.9310861, -88.7701448], [41.9310663, -88.7706495], [41.931059, -88.7708378]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3b035dac1bb30e9f9d3e09ec64567523);
#
#
#             map_3b035dac1bb30e9f9d3e09ec64567523.fitBounds(
#                 [[41.931059, -88.7708378], [41.9311206, -88.7657202]],
#                 {}
#             );
#
#
#             var marker_c835e543808ccb7df816d16e1d4610b2 = L.marker(
#                 [41.931361, -88.7653257],
#                 {}
#             ).addTo(map_3b035dac1bb30e9f9d3e09ec64567523);
#
#
#             var icon_a52ec10d7586acaf4b5060a70b51a51a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c835e543808ccb7df816d16e1d4610b2.setIcon(icon_a52ec10d7586acaf4b5060a70b51a51a);
#
#
#         var popup_830eb0e3d6320301bf9d5f8a98752c1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f8c2eadbc0f912b45292f921ffe978fc = $(`&lt;div id=&quot;html_f8c2eadbc0f912b45292f921ffe978fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NIU Computer Science Building&lt;/div&gt;`)[0];
#             popup_830eb0e3d6320301bf9d5f8a98752c1b.setContent(html_f8c2eadbc0f912b45292f921ffe978fc);
#
#
#         marker_c835e543808ccb7df816d16e1d4610b2.bindPopup(popup_830eb0e3d6320301bf9d5f8a98752c1b)
#         ;
#
#
#
#
#             var marker_328f064188971678cbbc0551e6a7cbc7 = L.marker(
#                 [41.93055745, -88.7709822],
#                 {}
#             ).addTo(map_3b035dac1bb30e9f9d3e09ec64567523);
#
#
#             var icon_8ca02e0af79b866b28cc47e488964624 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_328f064188971678cbbc0551e6a7cbc7.setIcon(icon_8ca02e0af79b866b28cc47e488964624);
#
#
#         var popup_bc4806cb95bfe7b44d67c8109f6febb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1b2a

# %%
#CHIPOTLE
import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim

ox.config(log_console=True, use_cache=True)

locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng

start_latlng = (41.931361, -88.7653257)
end_latlng = (41.9313782, -88.7716679)
start_location = "NIU Computer Science Building"
end_location = "Chipotle (1013 W Lincoln Hwy) Dekalb "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.9313782, -88.7716679))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.9313782, -88.7716679)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:47:13 Configured OSMnx 1.1.2
# 2022-05-02 16:47:13 HTTP response caching is on
# 2022-05-02 16:47:13 Retrieved response from cache file "cache/c11ac066b50965cb15fc132a0984ee25d209eecc.json"
# 2022-05-02 16:47:13 Created GeoDataFrame with 1 rows from 1 queries
# 2022-05-02 16:47:13 Constructed place geometry polygon(s) to query API
# 2022-05-02 16:47:13 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:13 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:13 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:13 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:13 Requesting data within polygon from API in 1 request(s)
# 2022-05-02 16:47:14 Retrieved response from cache file "cache/4df14a153707c0ba5aa56049b590b0cca3d22b69.json"
# 2022-05-02 16:47:14 Got all network data within polygon from API in 1 request(s)
# 2022-05-02 16:47:14 Creating graph from downloaded OSM data...
# 2022-05-02 16:47:14 Created graph with 37789 nodes and 77938 edges
# 2022-05-02 16:47:14 Added length attributes to graph edges
# 2022-05-02 16:47:14 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:15 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:16 Created r-tree spatial index for 37789 geometries
# 2022-05-02 16:47:16 Identified 35730 geometries inside polygon
# 2022-05-02 16:47:16 Removed 2059 nodes outside polygon
# 2022-05-02 16:47:16 Truncated graph by polygon
# 2022-05-02 16:47:17 Begin topologically simplifying the graph...
# 2022-05-02 16:47:17 Identified 4605 edge endpoints
# 2022-05-02 16:47:19 Simplified graph: 35730 to 4605 nodes, 73870 to 13006 edges
# 2022-05-02 16:47:19 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:19 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:19 Created r-tree spatial index for 4605 geometries
# 2022-05-02 16:47:19 Identified 4336 geometries inside polygon
# 2022-05-02 16:47:19 Removed 269 nodes outside polygon
# 2022-05-02 16:47:19 Removed 4 isolated nodes
# 2022-05-02 16:47:19 Got largest weakly connected component (4281 of 4332 total nodes)
# 2022-05-02 16:47:19 Truncated graph by polygon
# 2022-05-02 16:47:19 Counted undirected street segments incident on each node
# 2022-05-02 16:47:19 graph_from_polygon returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:19 graph_from_place returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:19 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:19 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:19 Created edges GeoDataFrame from graph
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12bc0f135b28b8c8229172cf42337385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12bc0f135b28b8c8229172cf42337385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_12bc0f135b28b8c8229172cf42337385 = L.map(
#                 &quot;map_12bc0f135b28b8c8229172cf42337385&quot;,
#                 {
#                     center: [41.931086025551934, -88.76907750929998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_094963e1cae8235071cd3ec047aae8cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_12bc0f135b28b8c8229172cf42337385);
#
#
#             var poly_line_dcddf3ff02d020e67c109c83fa3512d7 = L.polyline(
#                 [[41.9310983, -88.7657202], [41.9310995, -88.7658633], [41.9311012, -88.7659957], [41.9311206, -88.7670813], [41.9311133, -88.7671961]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_12bc0f135b28b8c8229172cf42337385);
#
#
#             var poly_line_bf9c6e1a13dbf9726104a384d26ac344 = L.polyline(
#                 [[41.9311133, -88.7671961], [41.9311127, -88.7672543], [41.9311124, -88.7672869], [41.9311125, -88.7680504], [41.9311135, -88.7682666], [41.9311166, -88.7684946], [41.9311162, -88.7685383], [41.9311145, -88.7687523], [41.9311154, -88.7689193], [41.9311113, -88.7691356], [41.9311051, -88.7693626], [41.931106, -88.769458], [41.9311045, -88.7695301], [41.9311007, -88.769708], [41.9310984, -88.7698172], [41.931098, -88.769838], [41.9310895, -88.770057], [41.9310861, -88.7701448], [41.9310663, -88.7706495], [41.931059, -88.7708378]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_12bc0f135b28b8c8229172cf42337385);
#
#
#             var poly_line_0a8b19eb1381520dc726e402385c90ba = L.polyline(
#                 [[41.931059, -88.7708378], [41.9310503, -88.7711367], [41.9310407, -88.7713203], [41.9310386, -88.7713616], [41.931026, -88.771757], [41.9310137, -88.7719736], [41.931009, -88.7720572], [41.9309982, -88.7722623], [41.9309976, -88.7722783], [41.9309917, -88.7724336]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_12bc0f135b28b8c8229172cf42337385);
#
#
#             map_12bc0f135b28b8c8229172cf42337385.fitBounds(
#                 [[41.9309917, -88.7724336], [41.9311206, -88.7657202]],
#                 {}
#             );
#
#
#             var marker_9a8e7b79231f16f7c09e7a3537474c50 = L.marker(
#                 [41.931361, -88.7653257],
#                 {}
#             ).addTo(map_12bc0f135b28b8c8229172cf42337385);
#
#
#             var icon_8ceae2c17190081e38927c9a4baa05dd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a8e7b79231f16f7c09e7a3537474c50.setIcon(icon_8ceae2c17190081e38927c9a4baa05dd);
#
#
#         var popup_a7e82f49d5ee8374021130a090b068c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_814649ec057691f9f1bcb28731d12f08 = $(`&lt;div id=&quot;html_814649ec057691f9f1bcb28731d12f08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NIU Computer Science Building&lt;/div&gt;`)[0];
#             popup_a7e82f49d5ee8374021130a090b068c2.setContent(html_814649ec057691f9f1b

# %%
#TACO BELL
import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim

ox.config(log_console=True, use_cache=True)

locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng

start_latlng = (41.931361, -88.7653257)
end_latlng = (41.9312187, -88.77647305)
start_location = "NIU Computer Science Building"
end_location = "Taco Bell ( 1209 W Lincoln Hwy ) Dekalb "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.9312187, -88.77647305))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.9312187, -88.77647305)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:47:19 Configured OSMnx 1.1.2
# 2022-05-02 16:47:19 HTTP response caching is on
# 2022-05-02 16:47:20 Retrieved response from cache file "cache/c11ac066b50965cb15fc132a0984ee25d209eecc.json"
# 2022-05-02 16:47:20 Created GeoDataFrame with 1 rows from 1 queries
# 2022-05-02 16:47:20 Constructed place geometry polygon(s) to query API
# 2022-05-02 16:47:20 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:20 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:20 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:20 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:20 Requesting data within polygon from API in 1 request(s)
# 2022-05-02 16:47:20 Retrieved response from cache file "cache/4df14a153707c0ba5aa56049b590b0cca3d22b69.json"
# 2022-05-02 16:47:20 Got all network data within polygon from API in 1 request(s)
# 2022-05-02 16:47:20 Creating graph from downloaded OSM data...
# 2022-05-02 16:47:21 Created graph with 37789 nodes and 77938 edges
# 2022-05-02 16:47:21 Added length attributes to graph edges
# 2022-05-02 16:47:21 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:22 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:23 Created r-tree spatial index for 37789 geometries
# 2022-05-02 16:47:23 Identified 35730 geometries inside polygon
# 2022-05-02 16:47:23 Removed 2059 nodes outside polygon
# 2022-05-02 16:47:23 Truncated graph by polygon
# 2022-05-02 16:47:23 Begin topologically simplifying the graph...
# 2022-05-02 16:47:24 Identified 4605 edge endpoints
# 2022-05-02 16:47:26 Simplified graph: 35730 to 4605 nodes, 73870 to 13006 edges
# 2022-05-02 16:47:26 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:26 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:26 Created r-tree spatial index for 4605 geometries
# 2022-05-02 16:47:26 Identified 4336 geometries inside polygon
# 2022-05-02 16:47:26 Removed 269 nodes outside polygon
# 2022-05-02 16:47:26 Removed 4 isolated nodes
# 2022-05-02 16:47:26 Got largest weakly connected component (4281 of 4332 total nodes)
# 2022-05-02 16:47:26 Truncated graph by polygon
# 2022-05-02 16:47:26 Counted undirected street segments incident on each node
# 2022-05-02 16:47:26 graph_from_polygon returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:26 graph_from_place returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:26 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:26 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:26 Created edges GeoDataFrame from graph
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b5d6eda11c07da5299026dfa925a741 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b5d6eda11c07da5299026dfa925a741&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1b5d6eda11c07da5299026dfa925a741 = L.map(
#                 &quot;map_1b5d6eda11c07da5299026dfa925a741&quot;,
#                 {
#                     center: [41.9310698926648, -88.76962363750472],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0c6765cc6b006436b6b14fe8e4cd5a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b5d6eda11c07da5299026dfa925a741);
#
#
#             var poly_line_29b42ef540c1b1a95cb6f398b314d627 = L.polyline(
#                 [[41.9310983, -88.7657202], [41.9310995, -88.7658633], [41.9311012, -88.7659957], [41.9311206, -88.7670813], [41.9311133, -88.7671961]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b5d6eda11c07da5299026dfa925a741);
#
#
#             var poly_line_86d96ae04a6e39ed0a6c91d7bfaa1a14 = L.polyline(
#                 [[41.9311133, -88.7671961], [41.9311127, -88.7672543], [41.9311124, -88.7672869], [41.9311125, -88.7680504], [41.9311135, -88.7682666], [41.9311166, -88.7684946], [41.9311162, -88.7685383], [41.9311145, -88.7687523], [41.9311154, -88.7689193], [41.9311113, -88.7691356], [41.9311051, -88.7693626], [41.931106, -88.769458], [41.9311045, -88.7695301], [41.9311007, -88.769708], [41.9310984, -88.7698172], [41.931098, -88.769838], [41.9310895, -88.770057], [41.9310861, -88.7701448], [41.9310663, -88.7706495], [41.931059, -88.7708378]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b5d6eda11c07da5299026dfa925a741);
#
#
#             var poly_line_e6c06bb2bc7126ed37f5dd0adc8e4ca0 = L.polyline(
#                 [[41.931059, -88.7708378], [41.9310503, -88.7711367], [41.9310407, -88.7713203], [41.9310386, -88.7713616], [41.931026, -88.771757], [41.9310137, -88.7719736], [41.931009, -88.7720572], [41.9309982, -88.7722623], [41.9309976, -88.7722783], [41.9309917, -88.7724336]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b5d6eda11c07da5299026dfa925a741);
#
#
#             var poly_line_cec2d0676240aca4342dc9d1922711f8 = L.polyline(
#                 [[41.9309917, -88.7724336], [41.930973, -88.772931], [41.930967, -88.773089]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1b5d6eda11c07da5299026dfa925a741);
#
#
#             var poly_line_3aa1a21f3ff268989f84f80e6064619d = L.polyline(
#                 [[41.930967, -88.773089], [41.9309603, -88.773249], [41.9309486, -88.7735257]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;rou

# %%
#DUNKIN
import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim

ox.config(log_console=True, use_cache=True)
locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng

start_latlng = (41.931361, -88.7653257)
end_latlng = (41.93135175, -88.7736953)
start_location = "NIU Computer Science Building"
end_location = "Dunkin ( 1101 W Lincoln Hwy ) Dekalb "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.93135175, -88.7736953))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.93135175, -88.7736953)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:47:26 Configured OSMnx 1.1.2
# 2022-05-02 16:47:26 HTTP response caching is on
# 2022-05-02 16:47:27 Retrieved response from cache file "cache/c11ac066b50965cb15fc132a0984ee25d209eecc.json"
# 2022-05-02 16:47:27 Created GeoDataFrame with 1 rows from 1 queries
# 2022-05-02 16:47:27 Constructed place geometry polygon(s) to query API
# 2022-05-02 16:47:27 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:27 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:27 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:27 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:27 Requesting data within polygon from API in 1 request(s)
# 2022-05-02 16:47:27 Retrieved response from cache file "cache/4df14a153707c0ba5aa56049b590b0cca3d22b69.json"
# 2022-05-02 16:47:27 Got all network data within polygon from API in 1 request(s)
# 2022-05-02 16:47:27 Creating graph from downloaded OSM data...
# 2022-05-02 16:47:28 Created graph with 37789 nodes and 77938 edges
# 2022-05-02 16:47:28 Added length attributes to graph edges
# 2022-05-02 16:47:28 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:29 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:29 Created r-tree spatial index for 37789 geometries
# 2022-05-02 16:47:30 Identified 35730 geometries inside polygon
# 2022-05-02 16:47:30 Removed 2059 nodes outside polygon
# 2022-05-02 16:47:30 Truncated graph by polygon
# 2022-05-02 16:47:30 Begin topologically simplifying the graph...
# 2022-05-02 16:47:31 Identified 4605 edge endpoints
# 2022-05-02 16:47:32 Simplified graph: 35730 to 4605 nodes, 73870 to 13006 edges
# 2022-05-02 16:47:33 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:33 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:33 Created r-tree spatial index for 4605 geometries
# 2022-05-02 16:47:33 Identified 4336 geometries inside polygon
# 2022-05-02 16:47:33 Removed 269 nodes outside polygon
# 2022-05-02 16:47:33 Removed 4 isolated nodes
# 2022-05-02 16:47:33 Got largest weakly connected component (4281 of 4332 total nodes)
# 2022-05-02 16:47:33 Truncated graph by polygon
# 2022-05-02 16:47:33 Counted undirected street segments incident on each node
# 2022-05-02 16:47:33 graph_from_polygon returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:33 graph_from_place returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:33 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:33 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:33 Created edges GeoDataFrame from graph
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c91d59d52b40df7340b873132bed4d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c91d59d52b40df7340b873132bed4d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5c91d59d52b40df7340b873132bed4d6 = L.map(
#                 &quot;map_5c91d59d52b40df7340b873132bed4d6&quot;,
#                 {
#                     center: [41.9310698926648, -88.76962363750472],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5066029ad2a8e126725ec3f6303b0a82 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5c91d59d52b40df7340b873132bed4d6);
#
#
#             var poly_line_0f105c89bd86ba6692d5f394d5d7c0d6 = L.polyline(
#                 [[41.9310983, -88.7657202], [41.9310995, -88.7658633], [41.9311012, -88.7659957], [41.9311206, -88.7670813], [41.9311133, -88.7671961]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c91d59d52b40df7340b873132bed4d6);
#
#
#             var poly_line_9c4a3aef576399fe965475b890c7b105 = L.polyline(
#                 [[41.9311133, -88.7671961], [41.9311127, -88.7672543], [41.9311124, -88.7672869], [41.9311125, -88.7680504], [41.9311135, -88.7682666], [41.9311166, -88.7684946], [41.9311162, -88.7685383], [41.9311145, -88.7687523], [41.9311154, -88.7689193], [41.9311113, -88.7691356], [41.9311051, -88.7693626], [41.931106, -88.769458], [41.9311045, -88.7695301], [41.9311007, -88.769708], [41.9310984, -88.7698172], [41.931098, -88.769838], [41.9310895, -88.770057], [41.9310861, -88.7701448], [41.9310663, -88.7706495], [41.931059, -88.7708378]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c91d59d52b40df7340b873132bed4d6);
#
#
#             var poly_line_d02339f63fa0bd5a5874121ad39a7311 = L.polyline(
#                 [[41.931059, -88.7708378], [41.9310503, -88.7711367], [41.9310407, -88.7713203], [41.9310386, -88.7713616], [41.931026, -88.771757], [41.9310137, -88.7719736], [41.931009, -88.7720572], [41.9309982, -88.7722623], [41.9309976, -88.7722783], [41.9309917, -88.7724336]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c91d59d52b40df7340b873132bed4d6);
#
#
#             var poly_line_502816548a5e785c3e71c8daa96d9b54 = L.polyline(
#                 [[41.9309917, -88.7724336], [41.930973, -88.772931], [41.930967, -88.773089]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c91d59d52b40df7340b873132bed4d6);
#
#
#             var poly_line_a92955b0e5e78038d81a2e88c046c949 = L.polyline(
#                 [[41.930967, -88.773089], [41.9309603, -88.773249], [41.9309486, -88.7735257]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;rou

# %%
#AMC Market Square 10
import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim


ox.config(log_console=True, use_cache=True)
locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng

start_latlng = (41.931361, -88.7653257)
end_latlng = (41.94727645, -88.72056275)
start_location = "NIU Computer Science Building"
end_location = "AMC Market Square 10 Dekalb "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.94727645, -88.72056275))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.94727645, -88.72056275)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:47:33 Configured OSMnx 1.1.2
# 2022-05-02 16:47:33 HTTP response caching is on
# 2022-05-02 16:47:34 Retrieved response from cache file "cache/c11ac066b50965cb15fc132a0984ee25d209eecc.json"
# 2022-05-02 16:47:34 Created GeoDataFrame with 1 rows from 1 queries
# 2022-05-02 16:47:34 Constructed place geometry polygon(s) to query API
# 2022-05-02 16:47:34 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:34 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:34 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:34 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:34 Requesting data within polygon from API in 1 request(s)
# 2022-05-02 16:47:34 Retrieved response from cache file "cache/4df14a153707c0ba5aa56049b590b0cca3d22b69.json"
# 2022-05-02 16:47:34 Got all network data within polygon from API in 1 request(s)
# 2022-05-02 16:47:34 Creating graph from downloaded OSM data...
# 2022-05-02 16:47:34 Created graph with 37789 nodes and 77938 edges
# 2022-05-02 16:47:35 Added length attributes to graph edges
# 2022-05-02 16:47:35 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:36 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:36 Created r-tree spatial index for 37789 geometries
# 2022-05-02 16:47:37 Identified 35730 geometries inside polygon
# 2022-05-02 16:47:37 Removed 2059 nodes outside polygon
# 2022-05-02 16:47:37 Truncated graph by polygon
# 2022-05-02 16:47:37 Begin topologically simplifying the graph...
# 2022-05-02 16:47:38 Identified 4605 edge endpoints
# 2022-05-02 16:47:39 Simplified graph: 35730 to 4605 nodes, 73870 to 13006 edges
# 2022-05-02 16:47:39 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:40 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:40 Created r-tree spatial index for 4605 geometries
# 2022-05-02 16:47:40 Identified 4336 geometries inside polygon
# 2022-05-02 16:47:40 Removed 269 nodes outside polygon
# 2022-05-02 16:47:40 Removed 4 isolated nodes
# 2022-05-02 16:47:40 Got largest weakly connected component (4281 of 4332 total nodes)
# 2022-05-02 16:47:40 Truncated graph by polygon
# 2022-05-02 16:47:40 Counted undirected street segments incident on each node
# 2022-05-02 16:47:40 graph_from_polygon returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:40 graph_from_place returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:40 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:40 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:40 Created edges GeoDataFrame from graph
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_692dfe9447bf57b7cd85e1201ff36168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_692dfe9447bf57b7cd85e1201ff36168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_692dfe9447bf57b7cd85e1201ff36168 = L.map(
#                 &quot;map_692dfe9447bf57b7cd85e1201ff36168&quot;,
#                 {
#                     center: [41.939861010166936, -88.7431638740843],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_128f00f869b3de08e345338c253abbf4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_692dfe9447bf57b7cd85e1201ff36168);
#
#
#             var poly_line_1fbb9b11c0e82f847413f78db61e2ffe = L.polyline(
#                 [[41.9310983, -88.7657202], [41.9311003, -88.7656101], [41.9310945, -88.7653769], [41.931068, -88.7643183], [41.9310162, -88.7621854], [41.9310134, -88.7620636]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_692dfe9447bf57b7cd85e1201ff36168);
#
#
#             var poly_line_fe813c46c1ef47fdc457c1189351ad26 = L.polyline(
#                 [[41.9310134, -88.7620636], [41.9310064, -88.7619133], [41.9309447, -88.7601414], [41.9309375, -88.7598723], [41.9309365, -88.7598429], [41.9309321, -88.7596023], [41.9309212, -88.7592657], [41.9309191, -88.7592023], [41.9309098, -88.7588971], [41.9309013, -88.7586156], [41.9308867, -88.7581352]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_692dfe9447bf57b7cd85e1201ff36168);
#
#
#             var poly_line_def7a8d6eb1f609cd60da524492dd90c = L.polyline(
#                 [[41.9308867, -88.7581352], [41.9308765, -88.7579665], [41.9308744, -88.7577727], [41.9308525, -88.7570815], [41.9308505, -88.7570621], [41.9308443, -88.7568778], [41.9308396, -88.7567378]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_692dfe9447bf57b7cd85e1201ff36168);
#
#
#             var poly_line_b0a69a5f9093983f0e91df487f9abec0 = L.polyline(
#                 [[41.9308396, -88.7567378], [41.9308203, -88.7559835], [41.9308131, -88.7557824], [41.9308061, -88.7555313], [41.9307886, -88.7549778], [41.9307784, -88.7548479], [41.9307742, -88.7545875], [41.9307736, -88.7545521]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_692dfe9447bf57b7cd85e1201ff36168);
#
#
#             var poly_line_434080f9faeaa066d9589f5fb0d6afd2 = L.polyline(
#                 [[41.9307736, -88.7545521], [41.9307661, -88.7543789], [41.930759, -88.754275], [41.9307509, -88.7541975], [41.930728, -88.754071]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&qu

# %%
#ELLWOOD HOUSE MUSEUM
import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim


ox.config(log_console=True, use_cache=True)
locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng

start_latlng = (41.931361, -88.7653257)
end_latlng = (41.93550345, -88.75347558)
start_location = "NIU Computer Science Building"
end_location = "ELLWOOD HOUSE MUSEUM Dekalb "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.93550345, -88.75347558))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.93550345, -88.75347558)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:47:40 Configured OSMnx 1.1.2
# 2022-05-02 16:47:40 HTTP response caching is on
# 2022-05-02 16:47:41 Retrieved response from cache file "cache/c11ac066b50965cb15fc132a0984ee25d209eecc.json"
# 2022-05-02 16:47:41 Created GeoDataFrame with 1 rows from 1 queries
# 2022-05-02 16:47:41 Constructed place geometry polygon(s) to query API
# 2022-05-02 16:47:41 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:41 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:41 Projected GeoDataFrame to +proj=utm +zone=16 +ellps=WGS84 +datum=WGS84 +units=m +no_defs +type=crs
# 2022-05-02 16:47:41 Projected GeoDataFrame to epsg:4326
# 2022-05-02 16:47:41 Requesting data within polygon from API in 1 request(s)
# 2022-05-02 16:47:41 Retrieved response from cache file "cache/4df14a153707c0ba5aa56049b590b0cca3d22b69.json"
# 2022-05-02 16:47:41 Got all network data within polygon from API in 1 request(s)
# 2022-05-02 16:47:41 Creating graph from downloaded OSM data...
# 2022-05-02 16:47:42 Created graph with 37789 nodes and 77938 edges
# 2022-05-02 16:47:42 Added length attributes to graph edges
# 2022-05-02 16:47:42 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:43 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:43 Created r-tree spatial index for 37789 geometries
# 2022-05-02 16:47:44 Identified 35730 geometries inside polygon
# 2022-05-02 16:47:44 Removed 2059 nodes outside polygon
# 2022-05-02 16:47:44 Truncated graph by polygon
# 2022-05-02 16:47:44 Begin topologically simplifying the graph...
# 2022-05-02 16:47:45 Identified 4605 edge endpoints
# 2022-05-02 16:47:47 Simplified graph: 35730 to 4605 nodes, 73870 to 13006 edges
# 2022-05-02 16:47:47 Identifying all nodes that lie outside the polygon...
# 2022-05-02 16:47:47 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:47 Created r-tree spatial index for 4605 geometries
# 2022-05-02 16:47:47 Identified 4336 geometries inside polygon
# 2022-05-02 16:47:47 Removed 269 nodes outside polygon
# 2022-05-02 16:47:47 Removed 4 isolated nodes
# 2022-05-02 16:47:47 Got largest weakly connected component (4281 of 4332 total nodes)
# 2022-05-02 16:47:47 Truncated graph by polygon
# 2022-05-02 16:47:47 Counted undirected street segments incident on each node
# 2022-05-02 16:47:47 graph_from_polygon returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:47 graph_from_place returned graph with 4281 nodes and 12191 edges
# 2022-05-02 16:47:47 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:47 Created nodes GeoDataFrame from graph
# 2022-05-02 16:47:47 Created edges GeoDataFrame from graph
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ebc03f4aadee42606e2f7541c285f54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ebc03f4aadee42606e2f7541c285f54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8ebc03f4aadee42606e2f7541c285f54 = L.map(
#                 &quot;map_8ebc03f4aadee42606e2f7541c285f54&quot;,
#                 {
#                     center: [41.932131365654755, -88.75845464579565],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_395e8eb76ce4a060c25350b38f51c314 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ebc03f4aadee42606e2f7541c285f54);
#
#
#             var poly_line_115b22ece9956decbec3abbed26c62cc = L.polyline(
#                 [[41.9310983, -88.7657202], [41.9311003, -88.7656101], [41.9310945, -88.7653769], [41.931068, -88.7643183], [41.9310162, -88.7621854], [41.9310134, -88.7620636]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ebc03f4aadee42606e2f7541c285f54);
#
#
#             var poly_line_bfc1ceb6e9dcebf72333e4e4f78387a3 = L.polyline(
#                 [[41.9310134, -88.7620636], [41.9310064, -88.7619133], [41.9309447, -88.7601414], [41.9309375, -88.7598723], [41.9309365, -88.7598429], [41.9309321, -88.7596023], [41.9309212, -88.7592657], [41.9309191, -88.7592023], [41.9309098, -88.7588971], [41.9309013, -88.7586156], [41.9308867, -88.7581352]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ebc03f4aadee42606e2f7541c285f54);
#
#
#             var poly_line_49567f909f7952dbcafec306a4f2167d = L.polyline(
#                 [[41.9308867, -88.7581352], [41.9310077, -88.758136], [41.9314326, -88.7581388]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ebc03f4aadee42606e2f7541c285f54);
#
#
#             var poly_line_2bf891b423543dc1edca3e9a1ff6cd31 = L.polyline(
#                 [[41.9314326, -88.7581388], [41.9314437, -88.7578552], [41.931447, -88.7577717]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ebc03f4aadee42606e2f7541c285f54);
#
#
#             var poly_line_a3842f52f3e6b64bda9a48247171f9af = L.polyline(
#                 [[41.931447, -88.7577717], [41.932636, -88.757755]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8ebc03f4aadee42606e2f7541c285f54);
#
#
#             var poly_line_eea9be033de031c25d39799fd8eca7c8 = L.polyline(
#                 [[41.932636, -88.757755], [41.9325699, -88.7567559]],
#                 {&

# %%
# VINNY PIZZZA

import osmnx as ox
import networkx as nx
import folium
import warnings
warnings.filterwarnings("ignore")
from geopy.geocoders import Nominatim


ox.config(log_console=True, use_cache=True)
locator = Nominatim(user_agent = "myapp")

# define the start and end locations in latlng

start_latlng = (41.931361, -88.7653257)
end_latlng = (41.931168, -88.7591379)
start_location = "NIU Computer Science Building"
end_location = "VINNY PIZZZA Dekalb "
# stores the start and end points as geopy.point.Point objects
start_latlng = locator.geocode(start_location).point

end_latlng = locator.geocode(end_location).point
# location where you want to find your route
place     = 'DeKalb, Illinois,United States'
# find shortest route based on the mode of travel
mode      = 'drive'       # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'length'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)
# find the nearest node to the start location
orig_node = ox.get_nearest_node(graph, (41.931361, -88.7653257))
# find the nearest node to the end location
dest_node = ox.get_nearest_node(graph, (41.931168, -88.7591379))
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
# # Marker class only accepts coordinates in tuple form
start_latlng = (41.931361, -88.7653257)
end_latlng   = (41.931168, -88.7591379)
start_marker = folium.Marker(
            location = start_latlng,
            popup = start_location,
            icon = folium.Icon(color='red'))
end_marker = folium.Marker(
            location = end_latlng,
            popup = end_location,
            icon = folium.Icon(color='green'))
# # add the circle marker to the map

shortest_route_map = ox.plot_route_folium(graph, shortest_route,tiles='openstreetmap')
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)

folium.TileLayer('openstreetmap').add_to(shortest_route_map)
folium.TileLayer('Stamen Terrain').add_to(shortest_route_map)
folium.TileLayer('Stamen Toner').add_to(shortest_route_map)
folium.TileLayer('Stamen Water Color').add_to(shortest_route_map)
folium.TileLayer('cartodbpositron').add_to(shortest_route_map)
folium.TileLayer('cartodbdark_matter').add_to(shortest_route_map)
folium.LayerControl().add_to(shortest_route_map)

shortest_route_map
# Out:
# 2022-05-02 16:47:47 Configured OSMnx 1.1.2
# 2022-05-02 16:47:47 HTTP response caching is on
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cd/pp_mmn_j6_5ddtv9yg3r3_kr0000gn/T/ipykernel_4177/1172791725.py in <module>
#      21 start_latlng = locator.geocode(start_location).point
#      22
# ---> 23 end_latlng = locator.geocode(end_location).point
#      24 # location where you want to find your route
#      25 place     = 'DeKalb, Illinois,United States'
#
# AttributeError: 'NoneType' object has no attribute 'point'
